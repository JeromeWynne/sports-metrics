# %%
# -*- coding: utf-8 -*-
import urllib.request
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup, SoupStrainer
import re
# %matplotlib inline

# %%
players_df = pd.read_csv('./data/epl/players.csv', index_col=0) # Some position information is missing!

# %%
app_goals_players = players_df.ix[((players_df.goals > 1) | players_df.appearances == 1) 
                                              & (players_df.goals == players_df.appearances)].index
players_df.ix[app_goals_players, 'goals'] = 0
total_goals_players = players_df.ix[players_df.goals >= 1].index
players_df.ix[total_goals_players, 'goals'] = (
                                players_df.ix[total_goals_players, 'goals']/players_df.ix[total_goals_players, 'appearances'])
corrupt_players = list(players_df.ix[players_df.total_pass < 1].index.values)
empty_players = list(players_df.ix[players_df.appearances < 40].index.values)
wrong_players = list(players_df.ix[(players_df.goals_conceded+players_df.clean_sheet) < players_df.appearances].index.values)
players_df.drop(corrupt_players+empty_players+wrong_players, inplace=True)

# %% [markdown]
# *Import and clean players dataset*

# %% [markdown]
# *Verify dataset integrity*

# %% [markdown]
# *Feature exploration and extraction*

# %% [markdown]
# Traits of an ideal feature:
#    - Is unique to a player: it would be the same regardless of the team they played for, or the teammates they played with.
#    - Is normalised.
#    - Is representative of a player's contribution to goals scored or conceded.
#    - A larger value indicates a better player

# %% [markdown]
# Rating metrics: Goalkeeper
# - Saves / (Saves + goals conceded) -> Fraction of shots saved
# - Clean sheets / Appearances -> Success rate of goalkeeper

# %% [markdown]
# Rating metrics:
# Defense
# - won tackles (%)
# - blocked shots per appearance
# - interceptions per appearance
# - clean sheets per appearance
# - clearances per appearance
# - duels won / total duels
# - battles won / battles lost
# - conceceded per appearance
#
# Rating metrics: Offense
# - Goals per appearance
# - Assists per appearance
# - Accurate crosses per appearance = (cross_accuracy x crosses)/appearances
# - Accurate long balls per appearance

# %%
players_df
# Out:
#                         Age Date of Birth Height         Nation    Position  \
# Abdoulaye Faye          NaN    26/02/1978    NaN        Senegal         NaN
# Andrew Johnson          NaN    10/02/1981    NaN        England         NaN
# Arouna Koné            33.0    11/11/1983  181cm  Cote D'Ivoire     Forward
# Ashley Westwood         NaN    01/04/1990    NaN        England  Midfielder
# Cameron Jerome          NaN    14/08/1986    NaN        England     Forward
# Chris Eagles            NaN    19/11/1985    NaN        England  Midfielder
# Dean Whitehead          NaN    21/01/1982    NaN        England  Midfielder
# Erik Nevland            NaN    10/11/1977    NaN         Norway         NaN
# Frank Lampard           NaN    20/06/1978    NaN        England         NaN
# Jay Rodriguez          27.0    29/07/1989  185cm        England     Forward
# Jefferson Montero      27.0    01/09/1989  173cm        Ecuador  Midfielder
# Luke Moore              NaN    13/02/1986    NaN        England         NaN
# Martin Olsson           NaN    17/05/1988    NaN         Sweden    Defender
# Mesut Özil             28.0    15/10/1988  180cm        Germany  Midfielder
# Michael Essien          NaN    03/12/1982    NaN          Ghana         NaN
# Michu                   NaN    21/03/1986    NaN          Spain     Forward
# Mohamed Diamé           NaN    14/06/1987    NaN        Senegal  Midfielder
# Nathan Baker            NaN    23/04/1991    NaN        England    Defender
# Nikica Jelavic          NaN    27/08/1985    NaN        Croatia         NaN
# Paul Scharner           NaN    11/03/1980    NaN        Austria         NaN
# Rickie Lambert          NaN    16/02/1982    NaN        England     Forward
# Ronnie Stam             NaN    18/06/1984    NaN    Netherlands    Defender
# Santiago Cazorla       32.0    13/12/1984  168cm          Spain  Midfielder
# Simon Francis          31.0    16/02/1985  183cm        England    Defender
# Thomas Vermaelen        NaN    14/11/1985    NaN        Belgium    Defender
# Tuncay Sanli            NaN    16/01/1982    NaN         Turkey         NaN
# Winston Reid           28.0    03/07/1988  190cm    New Zealand    Defender
# Albert Riera            NaN    15/04/1982    NaN          Spain  Midfielder
# Alexandre Song          NaN    09/09/1987    NaN       Cameroon         NaN
# Andy King              28.0    29/10/1988  183cm          Wales  Midfielder
# ...                     ...           ...    ...            ...         ...
# Andros Townsend        25.0    16/07/1991  181cm        England  Midfielder
# Angelo Ogbonna         28.0    23/05/1988  191cm          Italy    Defender
# Ciaran Clark            NaN    26/09/1989    NaN        Ireland    Defender
# David Wheater           NaN    14/02/1987    NaN        England    Defender
# Diniyar Bilyaletdinov   NaN    27/02/1985    NaN         Russia  Midfielder
# Emiliano Insúa          NaN    07/01/1989    NaN      Argentina    Defender
# Gary O'Neil             NaN    18/05/1983    NaN        England  Midfielder
# Graham Dorrans          NaN    05/05/1987    NaN       Scotland  Midfielder
# Harry Arter            27.0    28/12/1989  176cm        Ireland  Midfielder
# James Tomkins          27.0    29/03/1989  192cm        England    Defender
# Jason Puncheon         30.0    26/06/1986  173cm        England  Midfielder
# Javier Mascherano       NaN    08/06/1984    NaN      Argentina    Defender
# Johan Elmander          NaN    27/05/1981    NaN         Sweden     Forward
# John Ruddy              NaN    24/10/1986    NaN        England  Goalkeeper
# Leighton Baines        32.0    11/12/1984  170cm        England    Defender
# Leonardo Ulloa         30.0    26/07/1986  185cm      Argentina     Forward
# Mile Jedinak            NaN    03/08/1984    NaN      Australia  Midfielder
# Morgan Schneiderlin    27.0    08/11/1989  181cm         France  Midfielder
# Nemanja Matic          28.0    01/08/1988  194cm         Serbia  Midfielder
# Raheem Sterling        22.0    08/12/1994  170cm        England     Forward
# Ricardo Vaz Te          NaN    01/10/1986    NaN       Portugal         NaN
# Richard Garcia          NaN    04/09/1981    NaN      Australia         NaN
# Ron Vlaar               NaN    16/02/1985    NaN    Netherlands    Defender
# Sean Davis              NaN    20/09/1979    NaN        England         NaN
# Shaun Maloney          33.0    24/01/1983  170cm       Scotland  Midfielder
# Somen Tchoyi            NaN    29/01/1983    NaN       Cameroon         NaN
# Stephen Warnock         NaN    12/12/1981    NaN        England    Defender
# Steve Morison           NaN    29/08/1983    NaN          Wales     Forward
# Theo Walcott           27.0    16/03/1989  176cm        England     Forward
# Virgil van Dijk        25.0    08/07/1991  193cm    Netherlands    Defender
#
#                       Weight  accurate_cross  accurate_long_balls  \
# Abdoulaye Faye           NaN            36.0                237.0
# Andrew Johnson           NaN             NaN                  NaN
# Arouna Koné             78kg             NaN                  NaN
# Ashley Westwood          NaN            33.0                488.0
# Cameron Jerome           NaN             NaN                  NaN
# Chris Eagles             NaN            24.0                 30.0
# Dean Whitehead           NaN            21.0                426.0
# Erik Nevland             NaN             NaN                  NaN
# Frank Lampard            NaN            30.0                  1.0
# Jay Rodriguez           80kg             NaN                  NaN
# Jefferson Montero       68kg            20.0                 11.0
# Luke Moore               NaN             NaN                  NaN
# Martin Olsson            NaN            20.0                136.0
# Mesut Özil              76kg            37.0                137.0
# Michael Essien           NaN            14.0                527.0
# Michu                    NaN             NaN                  NaN
# Mohamed Diamé            NaN            21.0                412.0
# Nathan Baker             NaN            17.0                 95.0
# Nikica Jelavic           NaN             NaN                  NaN
# Paul Scharner            NaN            13.0                367.0
# Rickie Lambert           NaN             NaN                  NaN
# Ronnie Stam              NaN            15.0                 81.0
# Santiago Cazorla        66kg            24.0                438.0
# Simon Francis           90kg            23.0                248.0
# Thomas Vermaelen         NaN            22.0                326.0
# Tuncay Sanli             NaN             NaN                  NaN
# Winston Reid            87kg            15.0                374.0
# Albert Riera             NaN            22.0                 36.0
# Alexandre Song           NaN            18.0                508.0
# Andy King               75kg            16.0                 79.0
# ...                      ...             ...                  ...
# Andros Townsend         77kg            20.0                 28.0
# Angelo Ogbonna          86kg            40.0                118.0
# Ciaran Clark             NaN            22.0                265.0
# David Wheater            NaN            11.0                184.0
# Diniyar Bilyaletdinov    NaN            20.0                 26.0
# Emiliano Insúa           NaN            26.0                 59.0
# Gary O'Neil              NaN            27.0                379.0
# Graham Dorrans           NaN            22.0                293.0
# Harry Arter             70kg            30.0                159.0
# James Tomkins           74kg            35.0                468.0
# Jason Puncheon          70kg            28.0                264.0
# Javier Mascherano        NaN            16.0                680.0
# Johan Elmander           NaN             NaN                  NaN
# John Ruddy               NaN             NaN                718.0
# Leighton Baines         74kg            25.0                705.0
# Leonardo Ulloa          75kg             NaN                  NaN
# Mile Jedinak             NaN            28.0                226.0
# Morgan Schneiderlin     75kg            25.0                481.0
# Nemanja Matic           84kg            17.0                354.0
# Raheem Sterling         69kg             NaN                  NaN
# Ricardo Vaz Te           NaN             NaN                  NaN
# Richard Garcia           NaN            27.0                 28.0
# Ron Vlaar                NaN             6.0                246.0
# Sean Davis               NaN            30.0                283.0
# Shaun Maloney           69kg            24.0                 85.0
# Somen Tchoyi             NaN            16.0                 17.0
# Stephen Warnock          NaN            26.0                485.0
# Steve Morison            NaN             NaN                  NaN
# Theo Walcott            68kg             NaN                  NaN
# Virgil van Dijk         92kg            50.0                212.0
#
#                        aerial_lost  aerial_won     ...       \
# Abdoulaye Faye               125.0       284.0     ...
# Andrew Johnson                 NaN         NaN     ...
# Arouna Koné                    NaN         NaN     ...
# Ashley Westwood               71.0        43.0     ...
# Cameron Jerome                 NaN         NaN     ...
# Chris Eagles                  39.0        16.0     ...
# Dean Whitehead               143.0       112.0     ...
# Erik Nevland                   NaN         NaN     ...
# Frank Lampard                 85.0        64.0     ...
# Jay Rodriguez                  NaN         NaN     ...
# Jefferson Montero             36.0        21.0     ...
# Luke Moore                     NaN         NaN     ...
# Martin Olsson                154.0       180.0     ...
# Mesut Özil                    45.0        21.0     ...
# Michael Essien                97.0       142.0     ...
# Michu                          NaN         NaN     ...
# Mohamed Diamé                206.0       153.0     ...
# Nathan Baker                 181.0       253.0     ...
# Nikica Jelavic                 NaN         NaN     ...
# Paul Scharner                247.0       462.0     ...
# Rickie Lambert                 NaN         NaN     ...
# Ronnie Stam                   26.0         6.0     ...
# Santiago Cazorla              62.0        19.0     ...
# Simon Francis                104.0       173.0     ...
# Thomas Vermaelen             196.0       274.0     ...
# Tuncay Sanli                   NaN         NaN     ...
# Winston Reid                 187.0       318.0     ...
# Albert Riera                  64.0        36.0     ...
# Alexandre Song               158.0       190.0     ...
# Andy King                     61.0        68.0     ...
# ...                            ...         ...     ...
# Andros Townsend               25.0         3.0     ...
# Angelo Ogbonna                46.0        99.0     ...
# Ciaran Clark                 207.0       307.0     ...
# David Wheater                123.0       200.0     ...
# Diniyar Bilyaletdinov         65.0        36.0     ...
# Emiliano Insúa                36.0        35.0     ...
# Gary O'Neil                  133.0       100.0     ...
# Graham Dorrans                66.0        41.0     ...
# Harry Arter                   11.0        12.0     ...
# James Tomkins                258.0       518.0     ...
# Jason Puncheon                83.0        56.0     ...
# Javier Mascherano             93.0        52.0     ...
# Johan Elmander                 NaN         NaN     ...
# John Ruddy                     NaN         NaN     ...
# Leighton Baines              187.0       161.0     ...
# Leonardo Ulloa                 NaN         NaN     ...
# Mile Jedinak                 163.0       386.0     ...
# Morgan Schneiderlin          154.0       175.0     ...
# Nemanja Matic                144.0       188.0     ...
# Raheem Sterling                NaN         NaN     ...
# Ricardo Vaz Te                 NaN         NaN     ...
# Richard Garcia               124.0        61.0     ...
# Ron Vlaar                     83.0       124.0     ...
# Sean Davis                    32.0        17.0     ...
# Shaun Maloney                 52.0        12.0     ...
# Somen Tchoyi                  22.0        14.0     ...
# Stephen Warnock              135.0       160.0     ...
# Steve Morison                  NaN         NaN     ...
# Theo Walcott                   NaN         NaN     ...
# Virgil van Dijk               86.0       253.0     ...
#
#                        total_keeper_sweeper  total_offside  total_pass  \
# Abdoulaye Faye                          NaN           10.0       17.06
# Andrew Johnson                          NaN          123.0       11.90
# Arouna Koné                             NaN           34.0       22.38
# Ashley Westwood                         NaN            0.0       46.81
# Cameron Jerome                          NaN          128.0       15.10
# Chris Eagles                            NaN            4.0       23.01
# Dean Whitehead                          NaN            7.0       27.48
# Erik Nevland                            NaN           26.0        9.96
# Frank Lampard                           NaN           30.0       21.80
# Jay Rodriguez                           NaN           51.0       16.81
# Jefferson Montero                       NaN            8.0       13.45
# Luke Moore                              NaN           44.0        5.86
# Martin Olsson                           NaN           15.0       24.03
# Mesut Özil                              NaN           46.0       63.73
# Michael Essien                          NaN            4.0       45.72
# Michu                                   NaN           32.0       31.58
# Mohamed Diamé                           NaN            5.0       26.72
# Nathan Baker                            NaN            2.0       22.44
# Nikica Jelavic                          NaN          113.0       14.79
# Paul Scharner                           NaN           22.0       27.18
# Rickie Lambert                          NaN           79.0       24.02
# Ronnie Stam                             NaN            2.0       26.27
# Santiago Cazorla                        NaN            8.0       66.39
# Simon Francis                           NaN            2.0       54.37
# Thomas Vermaelen                        NaN            6.0       39.48
# Tuncay Sanli                            NaN           63.0       18.72
# Winston Reid                            NaN            4.0       27.90
# Albert Riera                            NaN            8.0       18.95
# Alexandre Song                          NaN            1.0       48.83
# Andy King                               NaN            2.0       24.21
# ...                                     ...            ...         ...
# Andros Townsend                         NaN            4.0       20.67
# Angelo Ogbonna                          NaN            0.0       36.39
# Ciaran Clark                            NaN            2.0       32.46
# David Wheater                           NaN            3.0       22.13
# Diniyar Bilyaletdinov                   NaN            6.0       17.53
# Emiliano Insúa                          NaN            1.0       41.98
# Gary O'Neil                             NaN           21.0       25.09
# Graham Dorrans                          NaN            4.0       31.27
# Harry Arter                             NaN            0.0       53.22
# James Tomkins                           NaN            4.0       29.39
# Jason Puncheon                          NaN           20.0       31.46
# Javier Mascherano                       NaN            2.0       56.96
# Johan Elmander                          NaN           54.0       20.36
# John Ruddy                             69.0            NaN       21.44
# Leighton Baines                         NaN           38.0       35.04
# Leonardo Ulloa                          NaN           20.0       18.12
# Mile Jedinak                            NaN            3.0       38.51
# Morgan Schneiderlin                     NaN            5.0       54.09
# Nemanja Matic                           NaN           11.0       55.94
# Raheem Sterling                         NaN           41.0       29.31
# Ricardo Vaz Te                          NaN           18.0        9.53
# Richard Garcia                          NaN            7.0       15.71
# Ron Vlaar                               NaN            0.0       31.59
# Sean Davis                              NaN            5.0       16.66
# Shaun Maloney                           NaN           18.0       29.55
# Somen Tchoyi                            NaN           21.0        9.24
# Stephen Warnock                         NaN            7.0       30.81
# Steve Morison                           NaN           22.0       12.66
# Theo Walcott                            NaN          117.0       16.21
# Virgil van Dijk                         NaN            2.0       43.57
#
#                        total_scoring_att  total_tackle  total_through_ball  \
# Abdoulaye Faye                       NaN         248.0                 2.0
# Andrew Johnson                     269.0          98.0                 NaN
# Arouna Koné                        148.0          54.0                 NaN
# Ashley Westwood                     92.0         203.0                13.0
# Cameron Jerome                     327.0         138.0                 NaN
# Chris Eagles                       162.0          92.0                32.0
# Dean Whitehead                      84.0         416.0                10.0
# Erik Nevland                        51.0          38.0                 NaN
# Frank Lampard                      832.0         491.0               205.0
# Jay Rodriguez                      223.0          92.0                 NaN
# Jefferson Montero                   37.0          64.0                 3.0
# Luke Moore                          82.0          48.0                 NaN
# Martin Olsson                        NaN         192.0                 4.0
# Mesut Özil                         132.0          97.0                89.0
# Michael Essien                     250.0         257.0                55.0
# Michu                              152.0          57.0                 NaN
# Mohamed Diamé                      239.0         602.0                44.0
# Nathan Baker                         NaN         106.0                 2.0
# Nikica Jelavic                     259.0          35.0                 NaN
# Paul Scharner                        NaN         415.0                17.0
# Rickie Lambert                     232.0          30.0                 NaN
# Ronnie Stam                          NaN         122.0                 8.0
# Santiago Cazorla                   313.0         213.0               129.0
# Simon Francis                        NaN         149.0                 0.0
# Thomas Vermaelen                     NaN         179.0                 7.0
# Tuncay Sanli                       194.0         119.0                 NaN
# Winston Reid                         NaN         219.0                 4.0
# Albert Riera                        72.0          52.0                10.0
# Alexandre Song                      91.0         563.0               167.0
# Andy King                           43.0          92.0                 2.0
# ...                                  ...           ...                 ...
# Andros Townsend                    176.0         151.0                 6.0
# Angelo Ogbonna                       NaN          67.0                 0.0
# Ciaran Clark                         NaN         241.0                 1.0
# David Wheater                        NaN         230.0                 3.0
# Diniyar Bilyaletdinov               71.0          58.0                17.0
# Emiliano Insúa                       NaN         130.0                 0.0
# Gary O'Neil                        138.0         346.0                18.0
# Graham Dorrans                     168.0         174.0                27.0
# Harry Arter                         60.0         103.0                10.0
# James Tomkins                        NaN         328.0                 3.0
# Jason Puncheon                     305.0         291.0                43.0
# Javier Mascherano                    NaN         535.0                16.0
# Johan Elmander                     233.0         215.0                 NaN
# John Ruddy                           NaN           NaN                 NaN
# Leighton Baines                      NaN         682.0                20.0
# Leonardo Ulloa                      87.0          82.0                 NaN
# Mile Jedinak                        77.0         269.0                 3.0
# Morgan Schneiderlin                101.0         427.0                17.0
# Nemanja Matic                       84.0         305.0                14.0
# Raheem Sterling                    252.0         169.0                 NaN
# Ricardo Vaz Te                      79.0          53.0                 NaN
# Richard Garcia                      34.0          57.0                 5.0
# Ron Vlaar                            NaN         137.0                 2.0
# Sean Davis                          86.0         282.0                13.0
# Shaun Maloney                      129.0          85.0                22.0
# Somen Tchoyi                        42.0          10.0                 5.0
# Stephen Warnock                      NaN         481.0                15.0
# Steve Morison                       70.0          12.0                 NaN
# Theo Walcott                       509.0         133.0                 NaN
# Virgil van Dijk                      NaN          98.0                 1.0
#
#                         wins  won_contest  won_tackle  yellow_card
# Abdoulaye Faye          56.0         21.0        81.0         32.0
# Andrew Johnson          65.0          NaN         NaN         14.0
# Arouna Koné             26.0          NaN         NaN          3.0
# Ashley Westwood         29.0         18.0        74.0         19.0
# Cameron Jerome          52.0          NaN         NaN         19.0
# Chris Eagles            17.0         81.0        82.0          4.0
# Dean Whitehead          61.0         26.0        71.0         50.0
# Erik Nevland            23.0          NaN         NaN          5.0
# Frank Lampard          349.0        129.0        71.0         59.0
# Jay Rodriguez           30.0          NaN         NaN          7.0
# Jefferson Montero       21.0        140.0        78.0          0.0
# Luke Moore              51.0          NaN         NaN          7.0
# Martin Olsson           37.0         76.0        78.0         11.0
# Mesut Özil              59.0        159.0        77.0          4.0
# Michael Essien         113.0        147.0        78.0         27.0
# Michu                   13.0          NaN         NaN          8.0
# Mohamed Diamé           43.0        310.0        74.0         25.0
# Nathan Baker            21.0          4.0        67.0         10.0
# Nikica Jelavic          37.0          NaN         NaN         12.0
# Paul Scharner           60.0         71.0        74.0         47.0
# Rickie Lambert          40.0          NaN         NaN          8.0
# Ronnie Stam              9.0         48.0        75.0          5.0
# Santiago Cazorla        78.0        268.0        76.0         12.0
# Simon Francis           18.0         43.0        75.0          8.0
# Thomas Vermaelen        64.0         28.0        75.0         13.0
# Tuncay Sanli            30.0          NaN         NaN         11.0
# Winston Reid            44.0         10.0        79.0         30.0
# Albert Riera            30.0         65.0        75.0          3.0
# Alexandre Song          97.0        158.0        78.0         43.0
# Andy King               26.0         20.0        79.0          5.0
# ...                      ...          ...         ...          ...
# Andros Townsend         37.0        201.0        84.0          9.0
# Angelo Ogbonna          18.0          8.0        81.0          7.0
# Ciaran Clark            31.0         38.0        76.0         40.0
# David Wheater           26.0          8.0        73.0         14.0
# Diniyar Bilyaletdinov   23.0         30.0        76.0          2.0
# Emiliano Insúa          27.0         40.0        74.0          2.0
# Gary O'Neil             59.0         68.0        74.0         38.0
# Graham Dorrans          40.0         77.0        71.0         21.0
# Harry Arter             13.0         38.0        79.0         11.0
# James Tomkins           54.0         16.0        75.0         25.0
# Jason Puncheon          49.0        229.0        77.0         19.0
# Javier Mascherano       50.0         58.0        78.0         22.0
# Johan Elmander          31.0          NaN         NaN         12.0
# John Ruddy              32.0          NaN         NaN          3.0
# Leighton Baines        142.0        217.0        76.0         43.0
# Leonardo Ulloa          31.0          NaN         NaN          3.0
# Mile Jedinak            23.0         21.0        75.0         16.0
# Morgan Schneiderlin     55.0         60.0        76.0         25.0
# Nemanja Matic           64.0        127.0        76.0         20.0
# Raheem Sterling         75.0          NaN         NaN         13.0
# Ricardo Vaz Te          28.0          NaN         NaN          7.0
# Richard Garcia          12.0         12.0        68.0          3.0
# Ron Vlaar               23.0         30.0        77.0          8.0
# Sean Davis              68.0         30.0        73.0         36.0
# Shaun Maloney           28.0         53.0        79.0          7.0
# Somen Tchoyi            11.0         31.0        80.0          0.0
# Stephen Warnock         82.0         99.0        73.0         38.0
# Steve Morison           17.0          NaN         NaN          1.0
# Theo Walcott           139.0          NaN         NaN          5.0
# Virgil van Dijk         23.0         23.0        76.0          5.0
#
# [703 rows x 56 columns]

# %%
def summarise_player(data):
    agg_data = pd.DataFrame()
    # concern - a player's stats are heavily influenced by who they play with
    # "we only hear see the bullet holes in planes that make it back"
    # defensive
    agg_data['save_rate'] = data['saves']/(data['saves'] + data['goals_conceded'])
    agg_data['cleans'] = data['clean_sheet']/data['appearances']
    agg_data['conceded'] = data['goals_conceded']/data['appearances']
    agg_data['tackles'] = data['won_tackle']/100
    # offensive
    agg_data['shots'] = data['ontarget_scoring_att']*data['total_scoring_att']/(100*data['appearances']) # on-target shots per appearance
    agg_data['scored'] = data['goals'] # goals per appearance
    agg_data['assists'] = data['goal_assist']/data['appearances'] # goal assists per appearance
    agg_data['crosses'] = data['accurate_cross']*data['total_cross']/(100*data['appearances']) # assume chance creations
    agg_data['appearances'] = data['appearances']
    return agg_data
